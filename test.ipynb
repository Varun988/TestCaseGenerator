# %%
from appconfig import AppConfig
from azureai import AzureAI
config = AppConfig()
azure_ai = AzureAI(config)
llm=azure_ai.get_client()

class LanguageValidator:
    """
    Validates if the programming language provided by the user matches the actual language of the code.
    """
    def __init__(self, openai_engine):
        self.openai_engine = openai_engine

    def detect_language(self, code):
        """
        Uses OpenAI to detect the programming language of the given code.
        """
        prompt = (
            "Analyze the following code and identify its programming language:\n\n"
            f"{code}\n\n"
            "Provide only the name of the programming language in your response."
        )
        try:
            response = llm.invoke(prompt)
            detected_language = response.content.strip()
            return detected_language
        except Exception as e:
            raise Exception(f"Error during language detection: {e}")

    def validate_language(self, expected_language, code):
        """
        Compares the detected programming language with the expected one.
        """
        detected_language = self.detect_language(code)
        if detected_language != expected_language.lower():
            raise ValueError(
                f"The input programming language '{expected_language}' does not match the detected language '{detected_language}'."
            )
        return detected_language
# Out:
# KUBERNETES_SERVICE_PORT_HTTPS=
# NODE_MAX_SPACE_SIZE=4096
# KUBERNETES_SERVICE_PORT=
# no_proxy=localhost,127.0.0.1,github.com,.github.com,.npmjs.org,.yarnpkg.com,npm.sap.com,.maven.apache.org,.repo-cache.svc.cluster.local
# SAP_UI_BOOTSTRAP_URL=https://sapui5.hana.ondemand.com
# CF_API_ENDPOINT=https://api.cf.eu10.hana.ondemand.com
# HOSTNAME=workspaces-ws-v7z9x-deployment-6b65f4755-4qtzs
# INTERNAL_LANDSCAPE=internalFalse
# SUBACCOUNT_ID=d79438d3-3873-4da0-9769-5ba543ad9894
# WING_EXT_INIT_PHASE_FIN_FILES=/extbin/simple-ext-installer.fin
# NODE_OPTIONS=--max-old-space-size=4096
# SIMPLE_EXTENSION_METADATA=...,...,...,...,...,...,...,...,...,...,...,...,...,,...
# NODE_EXTRA_CA_CERTS=/etc/ssl/certs/ca-certificates.crt
# LANDSCAPE_NAME=eu10
# BAS_DEFAULT_NODEJS_VERSION=20.18.1
# externalEntrypoint=https://coe-asset-b9jxgzf0.eu10cf.applicationstudio.cloud.sap
# BAS_DEFAULT_JAVA_VERSION=sapmachine-21.0.2
# EDITOR=code
# PWD=/local/source/openvscode-server
# BUILD_CODE_PLAN=standard
# NO_UPDATE_NOTIFIER=true
# USER_NAME=srrs@deloitte.com
# HOME=/home/user
# KUBERNETES_PORT_443_TCP=
# TENANT_PLAN=standard-edition
# BAS_DEFAULT_PYTHON_VERSION=3.11.2
# DESTINATION_PROXY_URL=http://secure-outbound-connectivity.webide-system
# SWA_FIELD_MAPPING=
# ASDF_DATA_DIR=/home/user/.asdf-inst
# https_proxy=http://127.0.0.1:8887
# OUTPUT_CHANNEL_TRACE_LOCATION=/extbin/generators/simple-extension-yo-install-output.txt
# SWA_TARGET_SITE_URL=https://webanalytics2.cfapps.eu10.hana.ondemand.com/tracker/log
# TENANT_SUBDOMAIN=coe-asset-b9jxgzf0
# SWA_MINIMAL_ALLOWED_VERSION=1.2.11
# TENANT_NAME=coe-asset-b9jxgzf0
# LANDSCAPE_ENVIRONMENT=live
# CF_PLUGIN_HOME=/local/cfplugins
# WS_BASE_URL=https://workspaces-ws-v7z9x.eu10.applicationstudio.cloud.sap/
# _SHARED_ENV=BUILD_CODE_PLAN: standard
# CDS_WATCH_DELAY: '"2000"'
# CF_API_ENDPOINT: https://api.cf.eu10.hana.ondemand.com
# DESTINATION_PROXY_URL: http://secure-outbound-connectivity.webide-system
# EXT_DESTINATION_PROXY_URL_HOST: eu10.applicationstudio.cloud.sap
# H2O_URL: https://coe-asset-b9jxgzf0.eu10cf.applicationstudio.cloud.sap
# HTTP_PROXY: http://127.0.0.1:8887
# HTTPS_PROXY: http://127.0.0.1:8887
# INTERNAL_LANDSCAPE: internalFalse
# LANDSCAPE_ENVIRONMENT: live
# LANDSCAPE_INFRASTRUCTURE: aws
# LANDSCAPE_NAME: eu10
# NO_PROXY: localhost,127.0.0.1,github.com,.github.com,.npmjs.org,.yarnpkg.com,npm.sap.com,.maven.apache.org,.repo-cache.svc.cluster.local
# NODE_MAX_SPACE_SIZE: "4096"
# NPM_CFG_REGISTRY: https://registry.npmjs.org
# NPM_CFG_SAP_REGISTRY: https://npm.sap.com/
# NPM_CONFIG_USERCONFIG: /home/user/.npmrc
# SAP_UI_BOOTSTRAP_URL: https://sapui5.hana.ondemand.com
# SIMPLE_EXTENSION_METADATA: ...,...,...,...,...,...,...,...,...,...,...,...,...,,...
# SUBACCOUNT_ID: d79438d3-3873-4da0-9769-5ba543ad9894
# SWA_EXCLUDED_ACCOUNTS: 
# SWA_FIELD_MAPPING: ""
# SWA_MINIMAL_ALLOWED_VERSION: 1.2.11
# SWA_TARGET_SITE_TOKEN: 95c7f8db-5d5a-43ba-8dfd-4b8e20486614
# SWA_TARGET_SITE_URL: https://webanalytics2.cfapps.eu10.hana.ondemand.com/tracker/log
# SWA_USER_ANON: literalTrue
# TENANT_PLAN: standard-edition
# TENANT_SUBDOMAIN: coe-asset-b9jxgzf0
# WING_EXT_INIT_PHASE_FIN_FILES: /extbin/simple-ext-installer.fin
# externalEntrypoint: https://coe-asset-b9jxgzf0.eu10cf.applicationstudio.cloud.sap
# http_proxy: http://127.0.0.1:8887
# https_proxy: http://127.0.0.1:8887
# no_proxy: localhost,127.0.0.1,github.com,.github.com,.npmjs.org,.yarnpkg.com,npm.sap.com,.maven.apache.org,.repo-cache.svc.cluster.local
# ownerFullName: Sreenivasan RS
# USER_NAME: "srrs@deloitte.com"
# WS_BASE_URL: https://workspaces-ws-v7z9x.eu10.applicationstudio.cloud.sap/
# WORKSPACE_ID: "workspaces-ws-v7z9x"
# TENANT_NAME: "coe-asset-b9jxgzf0"
# TENANT_ID: "d79438d3-3873-4da0-9769-5ba543ad9894"
# # Remove K8S env vars from shared env
# KUBERNETES_SERVICE_PORT_HTTPS:
# KUBERNETES_SERVICE_PORT:
# KUBERNETES_PORT_443_TCP:
# KUBERNETES_PORT_443_TCP_PROTO:
# KUBERNETES_PORT_443_TCP_ADDR:
# KUBERNETES_SERVICE_HOST:
# KUBERNETES_PORT:
# KUBERNETES_PORT_443_TCP_PORT:
# TENANT_LANDSCAPE_LABEL=n/a
# ASDF_DIR=/home/user/.asdf
# NO_PROXY=localhost,127.0.0.1,github.com,.github.com,.npmjs.org,.yarnpkg.com,npm.sap.com,.maven.apache.org,.repo-cache.svc.cluster.local
# NPM_CONFIG_USERCONFIG=/home/user/.npmrc
# VISUAL=code
# MBT_USE_DEFAULT="true"
# SHLVL=0
# LANDSCAPE_INFRASTRUCTURE=aws
# GIT_EDITOR=code --wait
# HTTPS_PROXY=http://127.0.0.1:8887
# SWA_USER_ANON=literalTrue
# KUBERNETES_PORT_443_TCP_PROTO=
# HTTP_PROXY=http://127.0.0.1:8887
# TENANT_ID=d79438d3-3873-4da0-9769-5ba543ad9894
# http_proxy=http://127.0.0.1:8887
# KUBERNETES_PORT_443_TCP_ADDR=
# NPM_CFG_REGISTRY=https://registry.npmjs.org
# H2O_URL=https://coe-asset-b9jxgzf0.eu10cf.applicationstudio.cloud.sap
# ownerFullName=Sreenivasan RS
# NODE_PATH=/extbin/npm/docker/lib/node_modules:/extbin/npm/globals/lib/node_modules:/managed-content/globals/pnpm/5/node_modules:/extbin/globals/pnpm/5/node_modules
# SWA_EXCLUDED_ACCOUNTS=
# KUBERNETES_SERVICE_HOST=api.eu10-prod.prod-aws.internal.live.k8s.ondemand.com
# KUBERNETES_PORT=
# KUBERNETES_PORT_443_TCP_PORT=
# BROWSER=open-browser
# PATH=/home/user/projects/.venv/bin:/extbin/local/openvscode-server/bin/remote-cli:/home/user/.asdf-inst/shims:/home/user/.asdf/bin:/home/user/.node_modules_global/bin:/home/user/.local/bin:/extbin/bin:/extbin/npm/docker/bin:/extbin/npm/globals/bin:/managed-content/globals/pnpm/bin:/extbin/globals/pnpm/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin
# WORKSPACE_ID=workspaces-ws-v7z9x
# SWA_TARGET_SITE_TOKEN=95c7f8db-5d5a-43ba-8dfd-4b8e20486614
# CDS_WATCH_DELAY="2000"
# NPM_CFG_SAP_REGISTRY=https://npm.sap.com/
# SIMPLE_EXT_NPMRC=/tmp/simple-ext/.npmrc
# EXT_DESTINATION_PROXY_URL_HOST=eu10.applicationstudio.cloud.sap
# OLDPWD=/home/user/.asdf
# LOG_CONFIG_PATH=/home/user/.webide/logs/sapTheiaExtLogConfig.yaml
# _=/home/user/projects/.venv/bin/python
# VSCODE_CWD=/local/source/openvscode-server
# VSCODE_NLS_CONFIG={"userLocale":"en","osLocale":"en","resolvedLanguage":"en","defaultMessagesFile":"/extbin/local/openvscode-server/out/nls.messages.json","locale":"en","availableLanguages":{}}
# VSCODE_HANDLES_SIGPIPE=true
# LS_COLORS=
# VSCODE_AMD_ENTRYPOINT=vs/workbench/api/node/extensionHostProcess
# VSCODE_HANDLES_UNCAUGHT_ERRORS=true
# ELECTRON_RUN_AS_NODE=1
# VSCODE_IPC_HOOK_CLI=/tmp/vscode-ipc-d9d8adf5-baba-4d63-afc0-d379fdf17549.sock
# SAP_UX_SET_CONTEXT=done
# VSCODE_L10N_BUNDLE_LOCATION=
# PYTHONUNBUFFERED=1
# VIRTUAL_ENV=/home/user/projects/.venv
# PYTHONIOENCODING=utf-8
# VIRTUAL_ENV_PROMPT=(.venv)
# PS1=(.venv)
# LC_CTYPE=C.UTF-8
# PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING=1
# PYDEVD_USE_FRAME_EVAL=NO
# TERM=xterm-color
# CLICOLOR=1
# FORCE_COLOR=1
# CLICOLOR_FORCE=1
# PAGER=cat
# GIT_PAGER=cat
# MPLBACKEND=module://matplotlib_inline.backend_inline
# SAP_API_VERSION=2023-05-15
# MODEL=gpt-4o
# AZURE_DEPLOYMENT_ID_4O=dff8ea76f841688c
# TEMPERATURE=0.0
# MAX_TOKENS=256
# ENV=LOCAL
# SAP_PROVIDER_URL=https://coe-asset-b9jxgzf0.authentication.eu10.hana.ondemand.com
# SAP_CLIENT_ID=sb-ba2bb4b5-c67c-4bff-ac21-96c32630e333!b501469|aicore!b540
# SAP_CLIENT_SECRET=3a1271b2-eb3c-4d6b-84ed-362406d7721a$sBbx_NWiYqxMo_M1INbnTYULbelgp2uYk3kXNtgEKzY=
# SAP_ENDPOINT_URL_GPT4O=https://api.ai.prod.eu-central-1.aws.ml.hana.ondemand.com
# AICORE_RESOURCE_GROUP=default
# SERP_API_KEY=581a16b1da3d5cc007c68da74265770f169d232360e2ac2a0dfb78f99a54f3a0
# TWITTER_CONSUMER_KEY=
# TWITTER_CONSUMER_SECRET=
# TWITTER_ACCESS_TOKEN=
# TWITTER_ACCESS_TOKEN_SECRET=

# %%
class LanguageValidator:
    """
    Validates if the programming language provided by the user matches the actual language of the code.
    """
    def __init__(self, openai_engine):
        self.openai_engine = openai_engine

    def detect_language(self, code):
        """
        Uses OpenAI to detect the programming language of the given code.
        """
        prompt = (
            "Analyze the following code and identify its programming language:\n\n"
            f"{code}\n\n"
            "Provide only the name of the programming language in your response."
        )
        try:
            response = llm.invoke(prompt)

            detected_language = response.content.strip().lower()
            return detected_language
        except Exception as e:
            raise Exception(f"Error during language detection: {e}")

    def validate_language(self, expected_language, code):
        """
        Compares the detected programming language with the expected one.
        """
        detected_language = self.detect_language(code)
        if detected_language != expected_language.lower():
            raise ValueError(
                f"The input programming language '{expected_language}' does not match the detected language '{detected_language}'."
            )
        return detected_language

# %%
class TestCaseGenerator:
    """
    Generates test cases for the given code in the specified programming language.
    """
    def __init__(self, openai_engine):
        self.openai_engine = openai_engine

    def generate_test_cases(self, language, code):
        """
        Uses OpenAI to generate test cases for the given code.
        """
        prompt = (
            f"Generate detailed test cases for the following {language} code:\n\n"
            f"{code}\n\n"
            "Provide the test cases in a clear and concise format."
        )
        try:
            response = llm.invoke(prompt)
            return response.content.strip()
        except Exception as e:
            raise Exception(f"Error during test case generation: {e}")


class TestCaseApp:
    """
    Manages the interaction between the user and the application.
    """
    def __init__(self, language_validator, test_case_generator):
        self.language_validator = language_validator
        self.test_case_generator = test_case_generator

    def run(self):
        """
        Main loop of the application.
        """
        print("Welcome to the Test Case Generator!")
        print("Provide the details below to generate test cases for your code.\n")

        # Collect inputs from the user
        programming_language = input("Enter the programming language (e.g., Python, JavaScript): ").strip()
        if not programming_language:
            print("Programming language cannot be empty.")
            return

        print("\nEnter the code for which you want test cases (press Enter twice to finish):")
        code_lines = []
        while True:
            line = input()
            if line == "":
                break
            code_lines.append(line)
        code_input = "\n".join(code_lines)

        if not code_input:
            print("Code cannot be empty.")
            return

        # Validate programming language
        try:
            print("\nValidating programming language...")
            detected_language = self.language_validator.validate_language(programming_language, code_input)
            print(f"Detected programming language: {detected_language.capitalize()}")
        except ValueError as ve:
            print(f"Error: {ve}")
            return
        except Exception as e:
            print(f"Unexpected error during validation: {e}")
            return

        # Generate test cases
        try:
            print("\nGenerating test cases...")
            test_cases = self.test_case_generator.generate_test_cases(programming_language, code_input)
            print("\nGenerated Test Cases:")
            print("-" * 30)
            print(test_cases)
        except Exception as e:
            print(f"Error during test case generation: {e}")


if __name__ == "__main__":
    # Create instances of the classes
    language_validator = LanguageValidator(openai_engine="YOUR_DEPLOYMENT_NAME")
    test_case_generator = TestCaseGenerator(openai_engine="YOUR_DEPLOYMENT_NAME")

    # Run the application
    app = TestCaseApp(language_validator, test_case_generator)
    app.run()
# Out:
# Welcome to the Test Case Generator!
# Provide the details below to generate test cases for your code.
#
#
# Enter the code for which you want test cases (press Enter twice to finish):
#
# Validating programming language...
# Detected programming language: Python
#
# Generating test cases...
#
# Generated Test Cases:
# ------------------------------
# To generate detailed test cases for the given Python code, we need to consider various scenarios, including valid inputs, invalid inputs, and edge cases. The code takes two inputs, converts them to integers, adds them, and prints the result. Here are the test cases:
#
# ### Test Case 1: Valid Integer Inputs
# - **Description**: Test with two valid integer inputs.
# - **Input**:
#   - `x = "5"`
#   - `y = "10"`
# - **Expected Output**:
#   - `The sum is: 15`
# - **Reasoning**: Both inputs are valid integers, and their sum is correctly calculated and displayed.
#
# ### Test Case 2: Valid Negative Integer Inputs
# - **Description**: Test with two valid negative integer inputs.
# - **Input**:
#   - `x = "-3"`
#   - `y = "-7"`
# - **Expected Output**:
#   - `The sum is: -10`
# - **Reasoning**: Both inputs are valid negative integers, and their sum is correctly calculated and displayed.
#
# ### Test Case 3: Mixed Positive and Negative Integer Inputs
# - **Description**: Test with one positive and one negative integer input.
# - **Input**:
